# %% [markdown]
# <a href="https://colab.research.google.com/github/c444roline/dxc-ai-maintenance-assistant/blob/main/DXC_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install docker.io
# !pip install localai
# !pip install ollama
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# docker.io is already the newest version (24.0.7-0ubuntu2~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
#text file preprocessing
from google.colab import files,drive #allow us to upload which files we want to preprocess
import pandas as pd

drive.mount('/content/drive')

# Path to your specific folder
data_path = '/content/drive/My Drive/DXC AI Studio DXC Team 3/Project Data Documents from Challenge Advisors/train/JPG'
data_path = '/content/drive/My Drive/DXC AI Studio DXC Team 3/Project Data Documents from Challenge Advisors/train/XML'

uploaded = files.upload() #use to upload csv of pdfs

# %%
def preprocessFile (filepath):
  dataCsv = pd.read_csv(filepath, on_bad_lines='skip')
  df = pd.DataFrame()
  df.dropna()

  print(dataCsv)#view what the file looks like

# %%
preprocessFile('Blow molding basics.csv')
# Out:
#                                                 Vol. 1 BLOW MOLDING  523
# 0                                         BLOW MOLDING          NaN  NaN
# 1                                         Introduction          NaN  NaN
# 2    Blow molding is deﬁned as a plastic process wh...          NaN  NaN
# 3    heated to its forming temperature, which is be...          NaN  NaN
# 4    being used; at its melting point it is made to...          NaN  NaN
# ..                                                 ...          ...  ...
# 707        B. Miller, Plast. World 30, 87 (July 1983).          NaN  NaN
# 708          D. L. Peters, Plast. Eng. 21 (Oct. 1982).          NaN  NaN
# 709        J. Szajna, Food Drug Packag. 14 (May 1983).          NaN  NaN
# 710                                                NaN  SAM BELCHER  NaN
# 711                                                NaN   Consultant  NaN
#
# [712 rows x 3 columns]
